# %%
url = "https://www.google.com/search?q=pretty+girl&tbm=isch&chips=q:pretty+girl,g_1:brown+hair:zbQfzN9btt0%3D&hl=en&sa=X&ved=2ahUKEwi608Gyu7b-AhW-NlkFHXX0A-8Q4lYoAXoECAEQMA&biw=980&bih=1076"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
img_tags = soup.find_all('img')

# %%
src_list = []
for img in img_tags:
    src = img.get('src')
    src_list.append(src)

with open('image_urls.txt', 'w') as f:
    for url in src_list:
        f.write("%s\n" % url)

# %%
with open('goog.txt', mode='r', encoding='utf-8') as f:
    file_contents = f.read()


new=file_contents.split(',')
# Out:
# Beautiful girls
#  Chicas hermosas
#  Belles filles
#  Schöne Mädchen
#  Ragazze bellissime
#  Meninas bonitas
#  Красивые девушки
#  美丽的女孩
#  美しい女の子
#  아름다운 소녀들
#  فتيات  جميلات
#  Güzel kızlar
#  Mooie meisjes
#  Vackra tjejer
#  Piękne dziewczyny
#  Όμορφα κορίτσια
#  Krásné dívky
#  Smukke piger
#  Kauniit tytöt
#
# Beautiful girls
#  Chicas hermosas
#  Belles filles
#  Schöne Mädchen
#  Ragazze bellissime
#  Meninas bonitas
#  Красивые девушки
#  美丽的女孩
#  美しい女の子
#  아름다운 소녀들
#  فتيات جميلات
#  Güzel kızlar
#  Mooie meisjes
#  Vackra tjejer
#  Piękne dziewczyny
#  Όμορφα κορίτσια
#  Krásné dívky
#  Smukke piger
#  Kauniit tytöt
#
# Blonde girls
#  Chicas rubias
#  Filles blondes
#  Blonde Mädchen
#  Ragazze bionde
#  Meninas loiras
#  Блондинки 金发女孩
#  ブロンドの女の子
#  금발 소녀들
#  فتيات شقراوات
# Sarışın kızlar
#  Blonde meisjes
#  Blonda tjejer
#  Blondynki
#  Ξανθιές κοπέλες
#  Blondýnky
#  Blonde piger
#  Vaaleat tytöt

# %%
import requests
from bs4 import BeautifulSoup
for i in new:
    url=(f'https://www.google.com/search?q={i}&tbm=isch&sxsrf=APwXEddnmV7hZuSsRs6DNdT3JfA-cBVxvA%3A1681931471790&source=hp&biw=1536&bih=703&ei=zzxAZLG2LdOq5NoPqPiliA4&iflsig=AOEireoAAAAAZEBK3-WbPeVLt5snuDH_DwNWsPgFuTYG&oq=pretty+g&gs_lcp=CgNpbWcQAxgBMgQIIxAnMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzILCAAQgAQQsQMQgwEyCAgAEIAEELEDOgcIIxDqAhAnULEDWLkaYI8iaAJwAHgAgAFTiAGaBZIBATmYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABCg&sclient=img')


    response = requests.get(url)
    filename = 'image_url22s.txt'
    soup = BeautifulSoup(response.content, 'html.parser')


    with open(filename, 'a') as f:
        for img_tag in soup.find_all('img'):
            src_value = img_tag['src']
            f.write(src_value + '\n')

# %%
import requests
from bs4 import BeautifulSoup

filename = 'image_urls.txt'
with open(filename, 'w') as f:
    for i in new:
        url = f'https://www.google.com/search?q={i}&tbm=isch&sxsrf=APwXEddnmV7hZuSsRs6DNdT3JfA-cBVxvA%3A1681931471790&source=hp&biw=1536&bih=703&ei=zzxAZLG2LdOq5NoPqPiliA4&iflsig=AOEireoAAAAAZEBK3-WbPeVLt5snuDH_DwNWsPgFuTYG&oq=pretty+g&gs_lcp=CgNpbWcQAxgBMgQIIxAnMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzILCAAQgAQQsQMQgwEyCAgAEIAEELEDOgcIIxDqAhAnULEDWLkaYI8iaAJwAHgAgAFTiAGaBZIBATmYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABCg&sclient=img'

        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')

        for img_tag in soup.find_all('img'):
            src_value = img_tag['src']
            f.write(src_value + '\n')

# %%
from selenium import webdriver
import logging

from bs4 import BeautifulSoup
import requests

from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import sqlite3


import random

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import mysql.connector

# MySQL veritabanına bağlanma
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Snit_6994",
  database="marlboro"
)

logging.basicConfig(filename='test.log', level=logging.INFO, format='%(asctime)s:%(levelname)s:%(message)s')

# Webdriver'ı başlatın ve Tinder'ın ana sayfasını yükleyin
driver = webdriver.Chrome()
driver.get("https://tinder.com")
logging.info('Tinder ana sayfası yüklendi')

random_number = random.randint(3, 8)

log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[text()='Log in']")))
log_in.click()
time.sleep(random_number)
logging.info('Ana ekran giris')

log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div[1]/div/div/div[3]/span/div[2]/button')))
log_in.click()
time.sleep(random_number)

logging.info('oturum acma baglantilari')
driver.save_screenshot("tinder_screenshot1.png")
driver.get("https://www.facebook.com/login.php?skip_api_login=1&api_key=464891386855067&kid_directed_site=0&app_id=464891386855067&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.8%2Fdialog%2Foauth%3Fapp_id%3D464891386855067%26cbt%3D1682322615334%26channel_url%3Dhttps%253A%252F%252Fstaticxx.facebook.com%252Fx%252Fconnect%252Fxd_arbiter%252F%253Fversion%253D46%2523cb%253Df210c84f8739374%2526domain%253Dtinder.com%2526is_canvas%253Dfalse%2526origin%253Dhttps%25253A%25252F%25252Ftinder.com%25252Ff2a97b2a1a43f38%2526relation%253Dopener%26client_id%3D464891386855067%26display%3Dpopup%26domain%3Dtinder.com%26e2e%3D%257B%257D%26fallback_redirect_uri%3Dhttps%253A%252F%252Ftinder.com%252F%26locale%3Den_US%26logger_id%3Dfe4a3c2a28899c%26origin%3D1%26redirect_uri%3Dhttps%253A%252F%252Fstaticxx.facebook.com%252Fx%252Fconnect%252Fxd_arbiter%252F%253Fversion%253D46%2523cb%253Df5c039785558a4%2526domain%253Dtinder.com%2526is_canvas%253Dfalse%2526origin%253Dhttps%25253A%25252F%25252Ftinder.com%25252Ff2a97b2a1a43f38%2526relation%253Dopener%2526frame%253Df2cfec0b0c5dda%26response_type%3Dtoken%252Csigned_request%252Cgraph_domain%26scope%3Duser_birthday%252Cuser_photos%252Cemail%252Cuser_likes%26sdk%3Djoey%26version%3Dv2.8%26ret%3Dlogin%26fbapp_pres%3D0%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fstaticxx.facebook.com%2Fx%2Fconnect%2Fxd_arbiter%2F%3Fversion%3D46%23cb%3Df5c039785558a4%26domain%3Dtinder.com%26is_canvas%3Dfalse%26origin%3Dhttps%253A%252F%252Ftinder.com%252Ff2a97b2a1a43f38%26relation%3Dopener%26frame%3Df2cfec0b0c5dda%26error%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied&display=popup&locale=en_US&pl_dbl=0")
email_log_in= driver.find_element(By.XPATH, '//*[@id="email"]')
email_log_in.click()
email_log_in.send_keys('2066876856')
logging.info('email girildi')

time.sleep(random_number)

password_log_in =driver.find_element(By.XPATH, '//*[@id="pass"]')
password_log_in.click()
time.sleep(random_number)
password_log_in.send_keys('Snit_6994')
time.sleep(random_number)
logging.info('sifre girildi')



submit_log_in =driver.find_element(By.ID, 'loginbutton').click()
time.sleep(random_number)
logging.info('fb girisi dogrulandi')

driver.get("https://tinder.com/app/recs")
log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[text()='Log in']")))
log_in.click()
time.sleep(random_number)

log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div[1]/div/div/div[3]/span/div[2]/button')))
log_in.click()
time.sleep(random_number)




#konuma izin ver
loca_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div/div[3]/button[1]'))).click()
driver.save_screenshot("tinder_screenshot4.png")
time.sleep(random_number)

#bildiimrlere izin verme 
notif_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div/div[3]/button[2]'))).click()
driver.save_screenshot("tinder_screenshot5.png")
time.sleep(random_number)
#cerezleri reddt
cook_log_in=WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o-1868991261"]/div/div[2]/div/div/div[1]/div[2]/button'))).click()
time.sleep(random_number)
driver.save_screenshot("tinder_screenshot.png")



logging.info('welcome to chicks heaven')


goddamnbutton=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[2]/div[3]').click()



logging.info('butona tiklandi')


bio =driver.find_element(By.ID, 'o-1868991261')
text1 = bio.text
driver.save_screenshot(f"chicky{i}.png")
logging.info(f' text{i} oldu ')
time.sleep(random_number)
goddamnbutton=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[2]/div[3]')
goddamnbutton.click()
like=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[2]/button')
like.click()
logging.info(f' begendi  {i}')
mycursor = mydb.cursor()
sql = "INSERT INTO marlborotable (text, image_path) VALUES (%s, %s)"
val = (text1, f"chicky{i}.png")
mycursor.execute(sql, val)
mydb.commit()
    



# WebDriver'ı kapatın
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[87], line 83
#      77 time.sleep(random_number)
#      82 #konuma izin ver
# ---> 83 loca_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div/div[3]/button[1]'))).click()
#      84 driver.save_screenshot("tinder_screenshot4.png")
#      85 time.sleep(random_number)
#
# File c:\Users\Salim\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\support\wait.py:95, in WebDriverWait.until(self, method, message)
#      93     if time.monotonic() > end_time:
#      94         break
# ---> 95 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x005BDCE3+50899]
# 	(No symbol) [0x0054E111]
# 	(No symbol) [0x00455588]
# 	(No symbol) [0x004808F9]
# ...

# %%
for i in range(20):
    bio =driver.find_element(By.ID, 'o-1868991261')
    text1 = bio.text
    driver.save_screenshot(f"chicky{i}.png")
    logging.info(f' text{i} oldu ')
    like=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[2]/button')
    like.click()
    logging.info(f' begendi  {i}') 
    
    # Verileri MySQL veritabanına yazdırma
    mycursor = mydb.cursor()
    sql = "INSERT INTO marlborotable (text, image_path) VALUES (%s, %s)"
    val = (text1, f"chicky{i}.png")
    mycursor.execute(sql, val)
    mydb.commit()

# %%
for i in range(2):
    
    bio =driver.find_element(By.ID, 'o-1868991261')
    text1 = bio.text
    driver.save_screenshot(f"chicky{i}.png")
    logging.info(f' text{i} oldu ')
    time.sleep(random_number)
    goddamnbutton=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[2]/div[3]')
    goddamnbutton.click()
    like=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[2]/div/div/div[2]/button')
    like.click()
    logging.info(f' begendi  {i}')
    mycursor = mydb.cursor()
    sql = "INSERT INTO marlborotable (text, image_path) VALUES (%s, %s)"
    val = (text1, f"chicky{i}.png")
    mycursor.execute(sql, val)
    mydb.commit()

# %%
import mysql.connector

# Veritabanı bağlantısı oluşturma
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Snit_6994"
)

# Veritabanı ve tablo oluşturma
mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE marlboro")
mycursor.execute("USE marlboro")
mycursor.execute("CREATE TABLE marlborotable (id INT AUTO_INCREMENT PRIMARY KEY, name VARCHAR(255), age INT)")

# %%
import random

names = ["Alice", "Bob", "Charlie", "David", "Emily", "Frank", "Grace", "Hannah", "Isaac", "John"]
ages = range(18, 70)

# Verileri ekleyin
for i in range(10):
    name = random.choice(names)
    age = random.choice(ages)
    sql = "INSERT INTO marlborotable (name, age) VALUES (%s, %s)"
    val = (name, age)
    mycursor.execute(sql, val)
    mydb.commit()

# %%
import mysql.connector

# Veritabanı bağlantısı oluşturma
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Snit_6994",
  database="marlboro"
)

# Cursor oluşturma ve sorguyu çalıştırma
mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM marlborotable")

# Sonuçları alıp ekrana yazdırma
myresult = mycursor.fetchall()
for x in myresult:
  print(x)
# Out:
# (1, 'Hannah', 67)
# (2, 'John', 42)
# (3, 'Bob', 39)
# (4, 'Emily', 41)
# (5, 'Frank', 22)
# (6, 'David', 55)
# (7, 'David', 65)
# (8, 'Frank', 67)
# (9, 'Emily', 24)
# (10, 'Grace', 48)

# %%
driver.save_screenshot("tinder_screenst.png")


like=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/div/main/div/div[1]/div[2]/div/div/div[4]/button').click()

infos_log_in =driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/div/main/div/div[1]/div[1]/div/div[2]/div[2]/div/text()')
print(infos_log_in)

time.sleep(5)

# %%
from selenium import webdriver
import logging

from bs4 import BeautifulSoup
import requests

from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import random

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
logging.basicConfig(filename='test.log', level=logging.INFO, format='%(asctime)s:%(levelname)s:%(message)s')

# Webdriver'ı başlatın ve Tinder'ın ana sayfasını yükleyin
driver = webdriver.Chrome()
driver.get("https://tinder.com")
logging.info('Tinder ana sayfası yüklendi')

random_number = random.randint(3, 8)


# Ekran görüntüsü alın

log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[text()='Log in']")))
log_in.click()
time.sleep(random_number)
logging.info('Ana ekran giris')

log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div[1]/div/div/div[3]/span/div[3]/button')))
log_in.click()
time.sleep(random_number)

logging.info('oturum acma baglantilari')
driver.save_screenshot("tinder_screenshot1.png")
#email_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="email"]')))
driver.get("https://www.facebook.com/login.php?skip_api_login=1&api_key=464891386855067&kid_directed_site=0&app_id=464891386855067&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.8%2Fdialog%2Foauth%3Fapp_id%3D464891386855067%26cbt%3D1682322615334%26channel_url%3Dhttps%253A%252F%252Fstaticxx.facebook.com%252Fx%252Fconnect%252Fxd_arbiter%252F%253Fversion%253D46%2523cb%253Df210c84f8739374%2526domain%253Dtinder.com%2526is_canvas%253Dfalse%2526origin%253Dhttps%25253A%25252F%25252Ftinder.com%25252Ff2a97b2a1a43f38%2526relation%253Dopener%26client_id%3D464891386855067%26display%3Dpopup%26domain%3Dtinder.com%26e2e%3D%257B%257D%26fallback_redirect_uri%3Dhttps%253A%252F%252Ftinder.com%252F%26locale%3Den_US%26logger_id%3Dfe4a3c2a28899c%26origin%3D1%26redirect_uri%3Dhttps%253A%252F%252Fstaticxx.facebook.com%252Fx%252Fconnect%252Fxd_arbiter%252F%253Fversion%253D46%2523cb%253Df5c039785558a4%2526domain%253Dtinder.com%2526is_canvas%253Dfalse%2526origin%253Dhttps%25253A%25252F%25252Ftinder.com%25252Ff2a97b2a1a43f38%2526relation%253Dopener%2526frame%253Df2cfec0b0c5dda%26response_type%3Dtoken%252Csigned_request%252Cgraph_domain%26scope%3Duser_birthday%252Cuser_photos%252Cemail%252Cuser_likes%26sdk%3Djoey%26version%3Dv2.8%26ret%3Dlogin%26fbapp_pres%3D0%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fstaticxx.facebook.com%2Fx%2Fconnect%2Fxd_arbiter%2F%3Fversion%3D46%23cb%3Df5c039785558a4%26domain%3Dtinder.com%26is_canvas%3Dfalse%26origin%3Dhttps%253A%252F%252Ftinder.com%252Ff2a97b2a1a43f38%26relation%3Dopener%26frame%3Df2cfec0b0c5dda%26error%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied&display=popup&locale=en_US&pl_dbl=0")
email_log_in= driver.find_element(By.XPATH, '//*[@id="email"]')
email_log_in.click()
email_log_in.send_keys('2066876856')

time.sleep(random_number)
logging.info('email girildi')

driver.save_screenshot("tinder_screenshot2.png")
#password_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="pass"]')))
password_log_in =driver.find_element(By.XPATH, '//*[@id="pass"]')
password_log_in.click()
time.sleep(random_number)
password_log_in.send_keys('Snit_6994')
time.sleep(random_number)
logging.info('sifre girildi')

driver.save_screenshot("tinder1.png")


submit_log_in =driver.find_element(By.ID, 'loginbutton').click()
time.sleep(random_number)
logging.info('fb girisi dogrulandi')

driver.get("https://tinder.com/app/recs")
log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[text()='Log in']")))
log_in.click()
time.sleep(random_number)

log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div[1]/div/div/div[3]/span/div[2]/button')))
log_in.click()
time.sleep(random_number)




#konuma izin ver
loca_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div/div[3]/button[1]'))).click()
driver.save_screenshot("tinder_screenshot4.png")
time.sleep(random_number)
#bildiimrlere izin verme 

notif_log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o697594959"]/main/div/div/div/div[3]/button[2]'))).click()
driver.save_screenshot("tinder_screenshot5.png")
time.sleep(random_number)
#cerezleri reddt
cook_log_in=WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o-1868991261"]/div/div[2]/div/div/div[1]/div[2]/button'))).click()
time.sleep(random_number)
driver.save_screenshot("tinder_screenshot.png")






logging.info('welcome to chicks heaven')
#info=WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/div/main/div/div[1]/div[1]/div/div[2]/div[2]/divtext()')))
#print(infos_log_in.text)

#info=driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/div/main/div/div/div[1]/div/div[2]/div[3]/button  ').click()
#logging.info(' info acildi ama text yazdirilamadi ')

#infos_log_in =driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/div/main/div/div[1]/div[1]/div/div[2]/div[2]/div/text()')
#print(infos_log_in)
#infos_log_in = driver.find_element(By.XPATH, '//*[@id="o-1868991261"]/div/div[1]/div/div/main/div/div[1]/div[1]/div/div[2]/div[2]/divtext()')
#print(infos_log_in.text)
driver.save_screenshot("tinder_ee.png")
logging.info('we DID IT')
















# Sayfayı indir
url = "https://tinder.com/app/recs"
response = requests.get(url)

# Sayfayı ayrıştır
soup = BeautifulSoup(response.content, "html.parser")

# Verileri al
infos_log_in = soup.select_one("#o-1868991261 > div > div:nth-of-type(1) > div > div > main > div > div:nth-of-type(1) > div:nth-of-type(1) > div > div:nth-of-type(2) > div:nth-of-type(2)").text

print(infos_log_in)







# WebDriver'ı kapatın
driver.quit()

# %%
from sqlalchemy import create_engine

# Database bağlantısı için gerekli bilgileri girin
DB_USER = "root"
DB_PASSWORD = "Snit_6994"
DB_HOST = "localhost"
DB_PORT = 3306
DB_NAME = "veritabani_adi"

# Veritabanı bağlantı URL'sini oluşturun
DATABASE_URI = f"mysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# SQLAlchemy Engine oluşturun
engine = create_engine(DATABASE_URI)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 14
#      11 DATABASE_URI = f"mysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
#      13 # SQLAlchemy Engine oluşturun
# ---> 14 engine = create_engine(DATABASE_URI)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\Salim\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# ...

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# Veritabanı bağlantısı oluşturma
engine = create_engine('postgresql://username:password@host:port/database')

# Oturum oluşturma
Session = sessionmaker(bind=engine)
session = Session()

# Verileri almak için bir döngü başlatma
while True:
    # Verileri al
    data = get_realtime_data()
    
    # Verileri SQL veritabanına kaydet
    try:
        for item in data:
            # Veritabanına kaydedilecek veri yapısına uygun bir şekilde düzenle
            record = MyTable(column1=item['value1'], column2=item['value2'], ...)
            session.add(record)
        session.commit()
    except Exception as e:
        print('Veritabanına kayıt hatası:', e)
        session.rollback()
    
    # Belirli bir aralıkta verileri çekmek için uyku süresi
    time.sleep(10)
# Out:
#   Cell In[23], line 20
#     record = MyTable(column1=item['value1'], column2=item['value2'], ...)
#                                                                         ^
# SyntaxError: positional argument follows keyword argument
